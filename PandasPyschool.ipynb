# %%
#Import Pandas, numpy

import pandas as pd
import numpy as np

#open and merge files
school_data_path="Resources/schools_complete.csv"
student_data_path="Resources/students_complete.csv"
school_df=pd.read_csv(school_data_path)
student_df=pd.read_csv(student_data_path)
#print(school_df).head
merge_df = pd.merge(school_df,student_df , on="school_name")
merge_df.head
# Out:
# <bound method NDFrame.head of        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
# ...

# %%
#collect new column info
Total_Schools =len(merge_df['school_name'].value_counts())
Total_Students=merge_df['student_name'].count()
Total_Budget=school_df['budget'].sum()


Average_Math =merge_df['math_score'].mean()
Average_Reader =merge_df['reading_score'].mean()

print (Total_Schools)
print(Total_Students)
print(Total_Budget)
print(Average_Math)
print(Average_Reader)
# Out:
# 15
# 39170
# 24649428
# 78.98537145774827
# 81.87784018381414

# %%
#Figure out Percentages for math and reading
PassMath = merge_df [(merge_df["math_score"] >=70)]
PassRead = merge_df [(merge_df["reading_score"] >=70)]
PassBoth = merge_df [(merge_df["reading_score"] >=70) & (merge_df["math_score"] >=70)]
PassMath1=len(PassMath)
PassRead1=len(PassRead)
PassBoth1=len(PassBoth)
PassMathAve=(PassMath1)/(Total_Students)*100
PassReadAve=(PassRead1)/(Total_Students)*100
PassBothAve=(PassBoth1)/(Total_Students)*100
print(PassMathAve)
print(PassReadAve)
print(PassBothAve)
# Out:
# 74.9808526933878
# 85.80546336482001
# 65.17232575950983

# %%
#Create District summary df
district_summary=[{"Total Schools":Total_Schools, "Total Students":Total_Students,
                   "Total Budget" :Total_Budget, "Average Math Score": Average_Math,\
                   "Average Reading Score":Average_Reader, "% Passing Math": PassMathAve, \
                   "% Passing Reading": PassReadAve, "% Overall Passing": PassBothAve}]
district_summary_df= pd.DataFrame(district_summary)
district_summary_df['Average Reading Score']=district_summary_df['Average Reading Score'].map("{:.2f}".format)
district_summary_df['Average Math Score']=district_summary_df['Average Math Score'].map("{:.2f}".format)
district_summary_df['% Passing Math']=district_summary_df['% Passing Math'].map("{:.2f}".format)
district_summary_df['% Passing Reading']=district_summary_df['% Passing Reading'].map("{:.2f}".format)
district_summary_df['% Overall Passing']=district_summary_df['% Overall Passing'].map("{:.2f}".format)
district_summary_df['Total Budget']=district_summary_df['Total Budget'].map("${:,.2f}".format)
district_summary_df
# Out:
#    Total Schools  Total Students    Total Budget Average Math Score  \
# 0             15           39170  $24,649,428.00              78.99
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.88          74.98             85.81             65.17

# %%
school_df.head
schoolsorted_df=school_df.sort_values(by='school_name')
schoolsorted_df
# Out:
#     School ID            school_name      type  size   budget
# 7           7     Bailey High School  District  4976  3124928
# 6           6    Cabrera High School   Charter  1858  1081356
# 1           1   Figueroa High School  District  2949  1884411
# 13         13       Ford High School  District  2739  1763916
# 4           4    Griffin High School   Charter  1468   917500
# 3           3  Hernandez High School  District  4635  3022020
# 8           8     Holden High School   Charter   427   248087
# 0           0      Huang High School  District  2917  1910635
# 12         12    Johnson High School  District  4761  3094650
# 9           9       Pena High School   Charter   962   585858
# 11         11  Rodriguez High School  District  3999  2547363
# 2           2    Shelton High School   Charter  1761  1056600
# 14         14     Thomas High School   Charter  1635  1043130
# 5           5     Wilson High School   Charter  2283  1319574
# ...

# %%
student_df
studentsorted_df=student_df.sort_values(by='school_name')
studentsorted_df
print(studentsorted_df)
mathscore=studentsorted_df["math_score"]
print(math_score)
grade_df=studentsorted_df["grade"]
#Locate schools type,budget, student budget from school da
# Out:
#        Student ID      student_name gender grade         school_name  \
# 19584       19584        Tammie Fox      F  11th  Bailey High School
# 21193       21193   Jennifer Murray      F   9th  Bailey High School
# 21192       21192       Lisa Pineda      F   9th  Bailey High School
# 21191       21191    Cameron Miller      M  11th  Bailey High School
# 21190       21190  Thomas Rasmussen      M  12th  Bailey High School
# ...           ...               ...    ...   ...                 ...
# 24829       24829       John Lozano      M  11th  Wright High School
# 24828       24828   Jonathan Thomas      M  12th  Wright High School
# 24827       24827      Lori Ramirez      F  10th  Wright High School
# 24797       24797       Scott Scott      M  10th  Wright High School
# 26035       26035    Michael Holmes      M   9th  Wright High School
#
#        reading_score  math_score
# 19584             82          92
# 21193             88          89
# 21192             86          67
# ...

# %%
#Locate schools type,budget, student budget from school data
school_names=schoolsorted_df["school_name"]
print(school_names)
school_types=schoolsorted_df["type"]
print(school_types)
total_students=schoolsorted_df["size"]
print(total_students)
school_budget=schoolsorted_df["budget"]
student_budget=(school_budget)/(total_students)
print(student_budget)
print(len(student_budget))

#print(math_score)
#math_score=student_df["math_score"].mean
#reading_score=student_df["reading_score"].mean
# Out:
# 7        Bailey High School
# 6       Cabrera High School
# 1      Figueroa High School
# 13         Ford High School
# 4       Griffin High School
# 3     Hernandez High School
# 8        Holden High School
# 0         Huang High School
# 12      Johnson High School
# 9          Pena High School
# 11    Rodriguez High School
# 2       Shelton High School
# 14       Thomas High School
# 5        Wilson High School
# 10       Wright High School
# Name: school_name, dtype: object
# 7     District
# 6      Charter
# 1     District
# 13    District
# 4      Charter
# 3     District
# 8      Charter
# 0     District
# 12    District
# 9      Charter
# 11    District
# 2      Charter
# 14     Charter
# 5      Charter
# 10     Charter
# Name: type, dtype: object
# 7     4976
# 6     1858
# 1     2949
# 13    2739
# 4     1468
# 3     4635
# 8      427
# 0     2917
# 12    4761
# 9      962
# 11    3999
# 2     1761
# 14    1635
# 5     2283
# 10    1800
# Name: size, dtype: int64
# ...

# %%
#find average math and reading score
math_scoreave_df= studentsorted_df.groupby("school_name")
avemath=math_scoreave_df["math_score"].mean()
print(math_score)
print(avemath)
print(len(avemath))
read_scoreave_df=studentsorted_df.groupby("school_name")
averead_df=read_scoreave_df["reading_score"].mean()
averead_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
PassMathAve=studentsorted_df[(studentsorted_df[math_score])] >=70
print(PassMathAve)
#PassReadAve_df= studentsorted_df[read_scoreave_df.reading_score>69].groupby(['school_name']).size()
#PassBothAve_df= [[studentsorted_df[student_df.math_score>69].groupby(['school_name'])]&[student_df[student_df.reading_score>69].groupby(['school_name'])].size()
# Out:
#        Student ID  student_name  gender  grade  school_name  reading_score  \
# 19584       False         False   False  False        False          False
# 21193       False         False   False  False        False          False
# 21192       False         False   False  False        False          False
# 21191       False         False   False  False        False          False
# 21190       False         False   False  False        False          False
# ...           ...           ...     ...    ...          ...            ...
# 24829       False         False   False  False        False          False
# 24828       False         False   False  False        False          False
# 24827       False         False   False  False        False          False
# 24797       False         False   False  False        False          False
# 26035       False         False   False  False        False          False
#
#        math_score
# 19584       False
# 21193       False
# ...

# %%
PassMath = merge_df [(merge_df["math_score"] >=70)]
PassMathAve=PassMath.groupby(["school_name"]).count()["student_name"]
totalMath=merge_df [(merge_df["math_score"] > 0)]
totalMathCount=totalMath.groupby(["school_name"]).count()["student_name"]
print(PassMathAve)
print(totalMathCount)
PassMassAvePerc=(PassMathAve/totalMathCount)*100
print(PassMassAvePerc)

PassRead = merge_df [(merge_df["reading_score"] >=70)]
PassReadAve=PassRead.groupby(["school_name"]).count()["student_name"]
PassReadAvePerc=(PassReadAve/totalMathCount)*100
print(PassReadAvePerc)
PassBoth = merge_df[(merge_df["reading_score"] >=70) & (merge_df["math_score"] >=70)]
PassBothAve=PassBoth.groupby(["school_name"]).count()["student_name"]
PassBothAvePerc=(PassBothAve/totalMathCount)*100
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: student_name, dtype: int64
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# ...

# %%
school_summary_df= pd.DataFrame({
         "School Name": school_names,
        "School Types":school_types,
   "Total Students":total_students,
    "Total School Budget":school_budget, 
    "Per Student Budget":student_budget, 
})

school_summary_df   


#mergeschooldistrict_df = pd.merge(school_summary_df,Math_df, on="school_name", how="Left") 
#mergeschooldistrict_df.head
# Out:
#               School Name School Types  Total Students  Total School Budget  \
# 7      Bailey High School     District            4976              3124928
# 6     Cabrera High School      Charter            1858              1081356
# 1    Figueroa High School     District            2949              1884411
# 13       Ford High School     District            2739              1763916
# 4     Griffin High School      Charter            1468               917500
# 3   Hernandez High School     District            4635              3022020
# 8      Holden High School      Charter             427               248087
# 0       Huang High School     District            2917              1910635
# 12    Johnson High School     District            4761              3094650
# 9        Pena High School      Charter             962               585858
# 11  Rodriguez High School     District            3999              2547363
# ...

# %%
Math_df = pd.DataFrame({ 
    "School Names": school_names,
    "Average Math Score": avemath,
   "Average Reading Score":averead_df,
 "% Passing Math":PassMassAvePerc,  
    "% Passing Reading": PassReadAvePerc,
    "% Overall Passing": PassBothAvePerc,
    })

Math_df

#mergeschooldistrict_df = pd.merge(school_summary_df,Math_df, on="[0]", how="Left") 
#mergeschooldistrict_df.head
# Out:
#                                 School Names  Average Math Score  \
# 0                          Huang High School                 NaN
# 1                       Figueroa High School                 NaN
# 2                        Shelton High School                 NaN
# 3                      Hernandez High School                 NaN
# 4                        Griffin High School                 NaN
# 5                         Wilson High School                 NaN
# 6                        Cabrera High School                 NaN
# 7                         Bailey High School                 NaN
# 8                         Holden High School                 NaN
# 9                           Pena High School                 NaN
# 10                        Wright High School                 NaN
# 11                     Rodriguez High School                 NaN
# 12                       Johnson High School                 NaN
# ...

# %%
mergeschooldistrict_df = pd.merge(school_summary_df,Math_df, on=[0], how="Left") 
mergeschooldistrict_df.head
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-38d0c27aa6fa> in <module>
# ----> 1 mergeschooldistrict_df = pd.merge(school_summary_df,Math_df, on=[0], how="Left")
#       2 mergeschooldistrict_df.head
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
# ...

# %%
#Top PErforming schools by %overal Passing
top_schools=Math_df.sort_values(['% Overall Passing'],ascending=False)
top_schools.head(5)
# Out:
#                      Average Math Score  Average Reading Score  \
# school_name
# Cabrera High School           83.061895              83.975780
# Thomas High School            83.418349              83.848930
# Griffin High School           83.351499              83.816757
# Wilson High School            83.274201              83.989488
# Pena High School              83.839917              84.044699
#
#                      % Passing Math  % Passing Reading  % Overall Passing
# school_name
# Cabrera High School       94.133477          97.039828          91.334769
# Thomas High School        93.272171          97.308869          90.948012
# Griffin High School       93.392371          97.138965          90.599455
# Wilson High School        93.867718          96.539641          90.582567
# Pena High School          94.594595          95.945946          90.540541

# %%
#Bottom Performing Schools by % overall PAssing
bottom_schools = Math_df.sort_values(['% Overall Passing'],ascending=True)
bottom_schools.head(5)
# Out:
#                       School Name  Average Math Score  Average Reading Score  \
# Rodriguez High School         NaN           76.842711              80.744686
# Figueroa High School          NaN           76.711767              81.158020
# Huang High School             NaN           76.629414              81.182722
# Hernandez High School         NaN           77.289752              80.934412
# Johnson High School           NaN           77.072464              80.966394
#
#                        % Passing Math  % Passing Reading  % Overall Passing
# Rodriguez High School       66.366592          80.220055          52.988247
# Figueroa High School        65.988471          80.739234          53.204476
# Huang High School           65.683922          81.316421          53.513884
# Hernandez High School       66.752967          80.862999          53.527508
# Johnson High School         66.057551          81.222432          53.539172

# %%
#Create grade/average math groups
nine_math=student_df.loc[student_df['grade']=="9th"].groupby('school_name')["math_score"].mean()
ten_math=student_df.loc[student_df['grade']=="10th"].groupby('school_name')["math_score"].mean()
eleven_math=student_df.loc[student_df['grade']=="11th"].groupby('school_name')["math_score"].mean()
twelve_math=student_df.loc[student_df['grade']=="12th"].groupby('school_name')["math_score"].mean()

math_score_df=pd.DataFrame({
    "9th":nine_math,
    "10th":ten_math,
    "11th":eleven_math,
    "12th":twelve_math
})
math_score=math_score[["9th","10th","11th","12th"]]
math_score.index.name="school_name"
math_score_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#REading Score by grade
#Create grade/average math groups
nine_read=student_df.loc[student_df['grade']=="9th"].groupby('school_name')["reading_score"].mean()
ten_read=student_df.loc[student_df['grade']=="10th"].groupby('school_name')["reading_score"].mean()
eleven_read=student_df.loc[student_df['grade']=="11th"].groupby('school_name')["reading_score"].mean()
twelve_read=student_df.loc[student_df['grade']=="12th"].groupby('school_name')["reading_score"].mean()

reading_score_df=pd.DataFrame({
    "9th":nine_read,
    "10th":ten_read,
    "11th":eleven_read,
    "12th":twelve_read
})
reading_score=reading_score[["9th","10th","11th","12th"]]
reading_score.index.name="school_name"
reading_score_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
#Scores by school Spending-Avemath,averead,percent math, percent read,percentread, overallpass
#
bins = [0,584, 624,645,]
group_labels = [" 0 to 584", "585 to 624", "625 to 645"]

pd.cut(school_summary_df["Per Student Budget"], bins, labels = group_labels).head()
school_summary_df["Per Student Budget and Testing"] =pd.cut(school_summary_df["Per Student Budget"], bins, labels=group_labels)
school_summary_df.head()

budgettesting = school_summary_df.groupby("Per Student Budget and Testing")
print(budgettesting["Per Student Budget"].count())
Math_df[["Average Math Score", "Average Reading Score", "% Passing Math","% Passing Reading","% Overall Passing"]].mean()
# Out:
# Per Student Budget and Testing
#  0 to 584     4
# 585 to 624    2
# 625 to 645    6
# Name: Per Student Budget, dtype: int64
# Average Math Score       80.432530
# Average Reading Score    82.529188
# % Passing Math           80.987054
# % Passing Reading        89.219023
# % Overall Passing        73.277560
# dtype: float64

# %%
#Scores by School Size
#Scores by school Spending-Avemath,averead,percent math, percent read,percentread, overallpass
#
bins = [0,1000,2000,4000,6000]
group_labels = [" 0 to 1000", "1001 to 2000", "2001 to 4000", "4001 plus"]

pd.cut(school_summary_df["Total Students"], bins, labels = group_labels).head()
school_summary_df["School Size and Testing"] =pd.cut(school_summary_df["Total Students"], bins, labels=group_labels)
school_summary_df.head()

sizetesting = school_summary_df.groupby("School Size and Testing")
print(sizetesting["Total Students"].count())
Math_df[["Average Math Score", "Average Reading Score", "% Passing Math","% Passing Reading","% Overall Passing"]].mean()
# Out:
# School Size and Testing
#  0 to 1000      2
# 1001 to 2000    5
# 2001 to 4000    5
# 4001 plus       3
# Name: Total Students, dtype: int64
# Average Math Score       80.432530
# Average Reading Score    82.529188
# % Passing Math           80.987054
# % Passing Reading        89.219023
# % Overall Passing        73.277560
# dtype: float64

# %%
#SCores by school type
#Scores by School Size
#Scores by school Spending-Avemath,averead,percent math, percent read,percentread, overallpass
#
bins = [Charter, District]
group_labels = ["Charter", "District"]

pd.cut(school_summary_df["School Type"], bins, labels = group_labels).head()
school_summary_df["School Type and Testing"] =pd.cut(school_summary_df["Type"], bins, labels=group_labels)
school_summary_df.head()

sizetesting = school_summary_df.groupby("School Type and Testing")
print(sizetesting["Total Students"].count())
Math_df[["Average Math Score", "Average Reading Score", "% Passing Math","% Passing Reading","% Overall Passing"]].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-7d063b2caa39> in <module>
#       3 #Scores by school Spending-Avemath,averead,percent math, percent read,percentread, overallpass
#       4 #
# ----> 5 bins = [Charter, District]
#       6 group_labels = ["Charter", "District"]
#       7
#
# NameError: name 'Charter' is not defined
